# %%
import pandas as pd

# %%
import pandas as pd

# 1️⃣ Read CSV
data = pd.read_csv("Muhurta.csv", encoding="latin1")
data.isna().sum()
# 2️⃣ Convert Date to datetime FIRST
data["Date"] = pd.to_datetime(
    data["Date"],
    errors="coerce",
    dayfirst=True
)

# 3️⃣ Sort while it's datetime
data = data.sort_values("Date")

# 4️⃣ Clean text columns (non-date)
def clean_text(value):
    if isinstance(value, str):
        return (
            value.replace("\u0096", "-")
                 .replace("\u2013", "-")
                 .replace("\u2014", "-")
        )
    return value

data = data.applymap(clean_text)

# 5️⃣ Format Date ONCE (calendar format)
data["Date"] = data["Date"].dt.strftime("%Y-%m-%d")
# Out:
# C:\Users\hosur\AppData\Local\Temp\ipykernel_3044\1269181515.py:26: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   data = data.applymap(clean_text)

# %%
data = pd.read_csv("Muhurta.csv", encoding="latin1")
data.isna().sum()
# Out:
# Muhurta Type        0
# Date                0
# Day                 0
# Month               0
# Paksha              0
# Tithi               0
# Nakshatra           6
# Lagna               0
# Time (From - To)    0
# dtype: int64

# %%
jsonData = data.to_json(orient='records',  force_ascii=False)

# %%
jsonData
# Out:
# '[{"Muhurta Type":"Vivaha (Marriage)","Date":"6\\/2\\/2025","Day":"Monday","Month":"Jyeshtha","Paksha":"Shukla","Tithi":"Saptami","Nakshatra":"Makha","Lagna":"Mithuna","Time (From - To)":"06:53 AM \x96 07:30 AM"},{"Muhurta Type":"Vivaha (Marriage)","Date":"6\\/5\\/2025","Day":"Thursday","Month":"Jyeshtha","Paksha":"Shukla","Tithi":"Dashami","Nakshatra":"Hasta","Lagna":"Mithuna","Time (From - To)":"07:52 AM \x96 08:51 AM"},{"Muhurta Type":"Vivaha (Marriage)","Date":"6\\/8\\/2025","Day":"Sunday","Month":"Jyeshtha","Paksha":"Shukla","Tithi":"Dwadashi","Nakshatra":"Swati","Lagna":"Mithuna","Time (From - To)":"07:40 AM \x96 08:39 AM"},{"Muhurta Type":"Vivaha (Marriage)","Date":"10\\/19\\/2025","Day":"Sunday","Month":"Ashwayuja","Paksha":"Krishna","Tithi":"Trayodashi","Nakshatra":"Uttara Phalguni","Lagna":"Vrishchika","Time (From - To)":"08:17 AM \x96 10:15 AM"},{"Muhurta Type":"Vivaha (Marriage)","Date":"2\\/6\\/2026","Day":"Friday","Month":"Magha","Paksha":"Shukla","Tithi":"Panchami","Nakshatra":"Hasta","Lagna":"Mesha","Time (From - To)":"10:54 AM \x96 11:09 AM"},{"Muhurta Type":"Vivaha (Marriage)","Date":"2\\/20\\/2026","Day":"Friday","Month":"Phalguna","Paksha":"Shukla","Tithi":"Tritiya","Nakshatra":"Uttara","Lagna":"Mesha","Time (From - To)":"09:58 AM \x96 11:05 AM"},{"Muhurta Type":"Vivaha (Marriage)","Date":"2\\/20\\/2026","Day":"Friday","Month":"Phalguna","Paksha":"Shukla","Tithi":"Tritiya","Nakshatra":"Uttara","Lagna":"Vrushabha","Time (From - To)":"12:38 PM \x96 01:30 PM"},{"Muhurta Type":"Vivaha (Marriage)","Date":"2\\/26\\/2026","Day":"Thursday","Month":"Phalguna","Paksha":"Shukla","Tithi":"Dashami","Nakshatra":"Mriga","Lagna":"Vrushabha","Time (From - To)":"11:23 AM \x96 12:10 PM"},{"Muhurta Type":"Vivaha (Marriage)","Date":"3\\/8\\/2026","Day":"Sunday","Month":"Phalguna","Paksha":"Shukla","Tithi":"Panchami","Nakshatra":"Swati","Lagna":"Vrushabha","Time (From - To)":"10:42 AM \x96 11:03 AM"},{"Muhurta Type":"Namakarana (Naming Ceremony)","Date":"4\\/23\\/2025","Day":"Wednesday","Month":"Chaitra","Paksha":"Krishna","Tithi":"Dashami","Nakshatra":"Dhanishta","Lagna":"Vrushabha","Time (From - To)":"09:15 AM \x96 09:28 AM"},{"Muhurta Type":"Namakarana (Naming Ceremony)","Date":"6\\/2\\/2025","Day":"Monday","Month":"Jyeshtha","Paksha":"Shukla","Tithi":"Saptami","Nakshatra":"Makha","Lagna":"Mithuna","Time (From - To)":"06:53 AM \x96 07:30 AM"},{"Muhurta Type":"Namakarana (Naming Ceremony)","Date":"6\\/5\\/2025","Day":"Thursday","Month":"Jyeshtha","Paksha":"Shukla","Tithi":"Dashami","Nakshatra":"Hasta","Lagna":"Mithuna","Time (From - To)":"07:52 AM \x96 08:51 AM"},{"Muhurta Type":"Namakarana (Naming Ceremony)","Date":"6\\/8\\/2025","Day":"Sunday","Month":"Jyeshtha","Paksha":"Shukla","Tithi":"Dwadashi","Nakshatra":"Swati","Lagna":"Mithuna","Time (From - To)":"07:40 AM \x96 08:39 AM"},{"Muhurta Type":"Namakarana (Naming Ceremony)","Date":"10\\/19\\/2025","Day":"Sunday","Month":"Ashwayuja","Paksha":"Krishna","Tithi":"Trayodashi","Nakshatra":"Uttara Phalguni","Lagna":"Vrishchika","Time (From - To)":"08:17 AM \x96 10:15 AM"},{"Muhurta Type":"Namakarana (Naming Ceremony)","Date":"2\\/6\\/2026","Day":"Friday","Month":"Magha","Paksha":"Shukla","Tithi":"Panchami","Nakshatra":"Hasta","Lagna":"Mesha","Time (From - To)":"10:54 AM \x96 11:09 AM"},{"Muhurta Type":"Namakarana (Naming Ceremony)","Date":"2\\/20\\/2026","Day":"Friday","Month":"Phalguna","Paksha":"Shukla","Tithi":"Tritiya","Nakshatra":"Uttara","Lagna":"Mesha","Time (From - To)":"09:58 AM \x96 11:05 AM"},{"Muhurta Type":"Namakarana (Naming Ceremony)","Date":"2\\/20\\/2026","Day":"Friday","Month":"Phalguna","Paksha":"Shukla","Tithi":"Tritiya","Nakshatra":"Uttara","Lagna":"Vrushabha","Time (From - To)":"12:38 PM \x96 01:30 PM"},{"Muhurta Type":"Namakarana (Naming Ceremony)","Date":"2\\/26\\/2026","Day":"Thursday","Month":"Phalguna","Paksha":"Shukla","Tithi":"Dashami","Nakshatra":"Mriga","Lagna":"Vrushabha","Time (From - To)":"11:23 AM \x96 12:10 PM"},{"Muhurta Type":"Namakarana (Nam ...

# %%
df = pd.read_csv('shubhakarya.csv', encoding='latin1')

# %%
df.isna().sum()
# Out:
# Muhurta Type        0
# Date                0
# Day                 0
# Month               0
# Paksha              0
# Tithi               0
# Nakshatra           6
# Lagna               0
# Time (From - To)    0
# dtype: int64
